# %%
from pylab import *

# %%
import numpy as np

# %%
a=np.loadtxt('./test3.csv', delimiter=',', skiprows=1)

# %%
plot(a[:,0],a[:,1]); xlabel('time (s)'); ylabel('Hertz')

# %%
hist(a[:,1])
# Out:
# (array([ 152.,   31.,   44.,   37.,   12.,    8.,    2.,    2.,    1.,    2.]),
#  array([ 1505.87 ,  1507.543,  1509.216,  1510.889,  1512.562,  1514.235,
#          1515.908,  1517.581,  1519.254,  1520.927,  1522.6  ]),
#  <a list of 10 Patch objects>)
